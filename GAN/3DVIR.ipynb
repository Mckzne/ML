# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/splits/brain_split/val/mr/1BA305_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BA247_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BC056_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BB151_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BB066_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BC053_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BB071_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BC073_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BC082_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BA005_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BA239_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BC077_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BC088_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BA358_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BC039_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BB030_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BB182_mr.nii
# /kaggle/input/splits/brain_split/val/mr/1BC051_mr.nii
# /kaggle/input/splits/brain_split/val/ct/1BA358_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BB182_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BC056_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BB151_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BB071_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BC073_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BC077_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BC082_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BA005_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BC051_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BC053_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BB066_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BB030_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BA239_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BA305_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BC039_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BA247_ct.nii
# /kaggle/input/splits/brain_split/val/ct/1BC088_ct.nii
# /kaggle/input/splits/brain_split/val/mask/1BB030_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BC056_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BA358_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BC073_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BA305_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BB066_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BB182_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BC077_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BB071_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BC088_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BC082_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BC051_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BA239_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BC053_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BB151_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BC039_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BA247_mask.nii
# /kaggle/input/splits/brain_split/val/mask/1BA005_mask.nii
# /kaggle/input/splits/brain_split/test/mr/1BA220_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BC035_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BB028_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BA172_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BA058_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BA141_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BB005_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BA040_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BA054_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BA359_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BA345_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BA379_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BA143_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BC019_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BB152_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BC052_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BC070_mr.nii
# /kaggle/input/splits/brain_split/test/mr/1BA159_mr.nii
# /kaggle/input/splits/brain_split/test/ct/1BA359_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BA040_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BC019_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BA143_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BA058_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BC052_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BA054_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BA220_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BA172_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BB028_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BB152_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BA379_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BB005_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BC070_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BA141_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BA159_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BA345_ct.nii
# /kaggle/input/splits/brain_split/test/ct/1BC035_ct.nii
# /kaggle/input/splits/brain_split/test/mask/1BA172_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BA141_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BA040_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BA220_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BA345_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BC070_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BB028_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BA143_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BA054_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BC035_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BB152_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BC052_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BA058_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BA359_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BA159_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BB005_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BA379_mask.nii
# /kaggle/input/splits/brain_split/test/mask/1BC019_mask.nii
# /kaggle/input/splits/brain_split/train/mr/1BC014_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB177_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB085_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB189_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB075_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC025_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC021_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB073_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC086_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC008_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB109_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC058_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB083_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA325_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB179_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA116_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB091_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB198_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA201_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC034_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB082_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA227_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC017_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB173_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA131_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC004_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB062_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB051_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA097_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB034_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC028_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC076_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA368_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA151_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB033_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA111_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA032_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA091_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB039_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB041_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC022_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB098_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB072_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC094_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC050_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC001_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC031_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA105_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA075_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA234_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC049_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB044_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA266_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC007_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC047_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB011_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB006_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB090_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA125_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB043_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB016_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC066_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB200_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC048_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC074_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC065_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB008_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA184_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB100_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC075_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC064_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA294_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB003_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB026_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA189_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC010_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC084_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC090_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC080_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC054_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB096_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC067_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB017_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB002_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB059_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA022_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC027_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA076_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA082_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA222_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA085_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB050_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA256_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB111_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB205_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA100_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC068_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB031_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC087_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC083_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB048_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC062_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC038_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA014_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA288_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA260_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB102_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB145_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA158_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB049_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB079_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA001_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA103_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA307_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC020_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC046_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC006_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC037_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB175_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA185_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA292_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA012_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB052_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA175_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC081_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC036_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA206_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB171_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC023_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC009_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB095_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB184_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA278_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA253_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC063_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA164_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC085_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA300_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB099_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BC041_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA328_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB076_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BB007_mr.nii
# /kaggle/input/splits/brain_split/train/mr/1BA336_mr.nii
# /kaggle/input/splits/brain_split/train/ct/1BB049_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB002_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC001_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB062_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB200_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC081_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA336_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC006_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC086_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC064_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA091_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB198_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB100_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA288_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA085_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC038_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB099_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA222_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB033_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB007_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA076_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA278_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB079_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA012_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB059_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA201_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA253_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB177_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC063_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA151_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA266_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB048_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB082_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB073_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA300_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA206_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA022_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA184_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB096_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB145_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC028_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA097_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC058_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA328_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC048_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB039_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC010_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC017_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA368_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA032_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB091_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA158_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC009_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB098_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC087_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC037_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC041_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB109_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB008_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA105_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB017_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB072_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC047_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC020_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC068_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA292_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC025_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB052_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC085_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB179_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA294_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB085_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC062_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA116_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC067_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB184_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA185_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA189_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB031_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA307_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA260_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA082_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB034_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB076_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC022_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB016_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC054_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB111_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB189_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA111_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC084_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA175_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC080_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB050_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC046_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB075_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA325_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA227_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB011_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC065_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB051_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA256_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB205_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB041_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB095_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA103_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC083_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA131_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC049_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC075_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC007_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB026_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB175_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA164_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB102_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC004_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC094_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB003_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA014_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC074_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC027_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA234_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB171_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC050_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB044_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC021_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB173_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC090_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC076_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB006_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC036_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC066_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA125_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC023_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC034_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA001_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB043_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB090_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BB083_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC008_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA100_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC014_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BA075_ct.nii
# /kaggle/input/splits/brain_split/train/ct/1BC031_ct.nii
# /kaggle/input/splits/brain_split/train/mask/1BC080_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC004_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC014_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA082_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB177_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB017_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA185_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB048_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC067_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB095_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA206_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB059_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA100_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA164_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB098_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB076_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB090_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB031_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB002_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA091_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB096_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB205_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA111_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA278_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC049_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC010_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB043_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC006_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA288_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB179_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA227_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA022_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB006_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB051_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB175_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC075_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC086_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA336_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB189_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA001_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB171_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA184_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC023_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA266_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB100_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA014_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC058_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA201_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA256_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB039_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC081_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB003_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC084_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC041_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC038_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB052_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA234_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB200_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB016_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA097_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA300_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC076_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA292_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB173_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC074_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC021_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB041_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC036_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC050_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB102_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA158_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA151_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA307_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA131_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB026_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC047_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC048_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC009_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA325_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB083_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA328_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC065_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC087_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA075_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB011_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC054_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB049_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB079_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB091_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC022_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB082_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB044_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC068_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC085_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC008_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC046_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC017_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA125_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB145_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA105_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB109_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA294_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB072_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA012_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC037_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC083_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC064_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC028_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA175_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA116_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC027_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC020_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB111_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB034_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB184_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA189_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB008_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC066_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC001_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB007_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA085_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB085_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA222_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC090_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB198_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB062_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA076_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB099_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC094_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB050_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB073_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC007_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC025_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC034_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA368_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC063_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA103_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA032_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB075_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC062_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BC031_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA260_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BA253_mask.nii
# /kaggle/input/splits/brain_split/train/mask/1BB033_mask.nii

# %%
import nibabel as nib
import numpy as np
import os
import random
import shutil
from pathlib import Path
from scipy.ndimage import affine_transform

# Define paths
split_dir = Path("/kaggle/input/splits/brain_split/train")
output_root = Path("/kaggle/working/train_transformed")

# Reset output directory
if output_root.exists():
    shutil.rmtree(output_root)
output_root.mkdir(parents=True, exist_ok=True)

for subfolder in ["ct", "mr", "mask"]:
    (output_root / subfolder).mkdir(parents=True, exist_ok=True)

# Transformation parameters
def generate_affine_matrix():
    angle = random.uniform(-5, 5) * np.pi / 180  # rotate max 5 degrees
    tx = random.uniform(-5, 5)  # translate max 5 pixels
    ty = random.uniform(-5, 5)

    cos_theta = np.cos(angle)
    sin_theta = np.sin(angle)
    
    matrix = np.array([
        [cos_theta, -sin_theta],
        [sin_theta,  cos_theta]
    ])
    offset = [tx, ty]

    return matrix, offset

# Get all CTs
ct_files = list((split_dir / "ct").glob("*.nii"))

# Shuffle for randomness
random.shuffle(ct_files)

# Transform 80%
num_transform = int(0.8 * len(ct_files))
transformed_cts = ct_files[:num_transform]
remaining_cts = ct_files[num_transform:]

# Apply transformations
for ct_path in transformed_cts:
    file_id = ct_path.stem.replace("_ct", "")
    mr_path = split_dir / "mr" / f"{file_id}_mr.nii"
    mask_path = split_dir / "mask" / f"{file_id}_mask.nii"

    ct_img = nib.load(ct_path)
    ct_data = ct_img.get_fdata()

    matrix, offset = generate_affine_matrix()

    transformed_data = np.zeros_like(ct_data)
    for i in range(ct_data.shape[2]):
        transformed_data[:, :, i] = affine_transform(
            ct_data[:, :, i], matrix, offset=offset, order=1, mode='nearest'
        )

    transformed_img = nib.Nifti1Image(transformed_data, ct_img.affine)
    nib.save(transformed_img, output_root / "ct" / f"{file_id}_ct.nii")

    shutil.copy(mr_path, output_root / "mr" / f"{file_id}_mr.nii")
    if mask_path.exists():
        shutil.copy(mask_path, output_root / "mask" / f"{file_id}_mask.nii")

# Copy remaining aligned CTs
for ct_path in remaining_cts:
    file_id = ct_path.stem.replace("_ct", "")
    mr_path = split_dir / "mr" / f"{file_id}_mr.nii"
    mask_path = split_dir / "mask" / f"{file_id}_mask.nii"

    shutil.copy(ct_path, output_root / "ct" / f"{file_id}_ct.nii")
    shutil.copy(mr_path, output_root / "mr" / f"{file_id}_mr.nii")
    if mask_path.exists():
        shutil.copy(mask_path, output_root / "mask" / f"{file_id}_mask.nii")

print(f"✅ Done! {len(transformed_cts)} CTs transformed (slice-by-slice), {len(remaining_cts)} kept original.")
# Out:
# ✅ Done! 115 CTs transformed (slice-by-slice), 29 kept original.
